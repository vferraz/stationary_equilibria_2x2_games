# %% [markdown]
# # Density Plots from Equilibria Computatations

# %% [markdown]
# This file is part of the reproduction package provided with the paper Stationary Equilibria in Behavioral Game Theory: An Experimental Analysis of Inspection Games.
#
# **IMPORTANT**<br>
# <span style="color:red">**The data files to generate these plots are particularly heavy since it contains the whole grids from the optimization search spaces. I believe they will not be in the downloadable folder due to the size issue**</span>. Please contact me if you would like to have the files. They can also be generated with the modified equilibrium computation code.
#
# Questions and correspondence should be addressed to Vinícius Ferraz (visferraz@gmail.com)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
neia = pd.read_csv('data_equilibria/sg_output_NEIA.csv')
ibeia = pd.read_csv('data_equilibria/sg_output_IBEIA.csv')
ibeia2 = pd.read_csv('data_equilibria/sg_output_IBE2IA.csv')
ibegamma = pd.read_csv('data_equilibria/sg_output_IBEGAMMA.csv')
qre = pd.read_csv('data_equilibria/qre_lambda_out.csv')

# %%
ibegammaia = pd.read_csv('sg_output_IBEGAMMAIA.csv') # this file is heavy and it takes a while to load

# %%
#neia = neia.loc[neia['q'] != 2]
neia = neia.loc[neia['framed'] == 1]
neia = neia.loc[neia['q'] != 2]

ibeia = ibeia.loc[ibeia['q'] != 2]
ibeia = ibeia.loc[ibeia['framed'] == 1]

ibeia2 = ibeia2.loc[ibeia2['q'] != 2]
ibeia2 = ibeia2.loc[ibeia2['framed'] == 1]

ibegamma = ibegamma.loc[ibegamma['q'] != 2]
ibegamma = ibegamma.loc[ibegamma['framed'] == 1]

# %%
ibegammaia = ibegammaia.loc[ibegammaia['q'] != 2]
ibegammaia = ibegammaia.loc[ibegammaia['framed'] == 1]

# %%
fr =[0.461,0.136]
uf =[0.341,0.108]

kwargs  =   {
             'linewidth':0.02, # line width of spot
             'alpha':0.3
            }
s=1

c_line='grey'
height_c = 3.6

# %%
g = sns.JointGrid(data=neia, x="PU", y="QL",height=height_c)
g.plot_joint(sns.scatterplot, s=s,**kwargs)
g.ax_joint.scatter(fr[0],fr[1], c='red', marker='x', s=75, label='framed_mean')
g.ax_joint.scatter(uf[0],uf[1], c='blue', marker='+', s=125, label='framed_mean')
g.plot_marginals(sns.kdeplot, fill=True)
g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("NE◦IA(α,β)")
plt.savefig('neia.png', format='png', dpi=1200, transparent=True)

# %%
qre = qre.rename(columns={"p1_s1": "PU", "p2_s1": "QL"})
g = sns.JointGrid(data=qre, x="PU", y="QL",height=height_c)
g.plot_joint(sns.scatterplot, s=s,**kwargs)
g.ax_joint.scatter(fr[0],fr[1], c='red', marker='x', s=75, label='framed_mean')
g.ax_joint.scatter(uf[0],uf[1], c='blue', marker='+', s=125, label='framed_mean')
g.plot_marginals(sns.kdeplot, fill=True)
g.fig.suptitle("QREλ")
# Out:
# Text(0.5, 0.98, 'QREλ')

# %%
g = sns.JointGrid(data=ibeia, x="PU", y="QL",height=height_c)
g.plot_joint(sns.scatterplot, s=s,**kwargs)
g.ax_joint.scatter(fr[0],fr[1], c='red', marker='x', s=75, label='framed_mean')
g.ax_joint.scatter(uf[0],uf[1], c='blue', marker='+', s=125, label='framed_mean')
g.plot_marginals(sns.kdeplot, fill=True)
g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=ibeia2, x="PU", y="QL",height=height_c)
g.plot_joint(sns.scatterplot, s=s,**kwargs)
g.ax_joint.scatter(fr[0],fr[1], c='red', marker='x', s=75, label='framed_mean')
g.ax_joint.scatter(uf[0],uf[1], c='blue', marker='+', s=125, label='framed_mean')
g.plot_marginals(sns.kdeplot, fill=True)
g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=ibegamma, x="PU", y="QL",height=height_c)
g.plot_joint(sns.scatterplot, s=s,**kwargs)
g.ax_joint.scatter(fr[0],fr[1], c='red', marker='x', s=75, label='framed_mean')
g.ax_joint.scatter(uf[0],uf[1], c='blue', marker='+', s=125, label='framed_mean')
g.plot_marginals(sns.kdeplot, fill=True)
g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("IBEγ")

# %%
# %%time
g = sns.JointGrid(data=ibegammaia, x="PU", y="QL",height=height_c)
g.plot_joint(sns.scatterplot, s=s,**kwargs)
g.ax_joint.scatter(fr[0],fr[1], c='red', marker='x', s=75, label='framed_mean')
g.ax_joint.scatter(uf[0],uf[1], c='blue', marker='+', s=125, label='framed_mean')
g.plot_marginals(sns.kdeplot, fill=True)
g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("IBEγ◦IA(α,β)")
