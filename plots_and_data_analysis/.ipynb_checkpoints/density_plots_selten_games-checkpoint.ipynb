# %% [markdown]
# # Density Plots from Equilibria Computatations - 12 Games

# %% [markdown]
# This file is part of the reproduction package provided with the paper Stationary Equilibria in Behavioral Game Theory: An Experimental Analysis of Inspection Games.
#
# This code generates the density plots for the prediction grids for the 12 games in Selten and Chmura (2008)
#
# **IMPORTANT**<br>
# <span style="color:red">**The data files to generate these plots are particularly heavy since it contains the whole grids from the optimization search spaces. I believe they will not be in the downloadable folder due to the size issue**</span>. Please contact me if you would like to have the files. They can also be generated with the modified equilibrium computation code.
#
# Questions and correspondence should be addressed to Vinícius Ferraz (visferraz@gmail.com)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings


warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
g1 = [0.079,0.69]
g2 = [0.217,0.527]
g3 = [0.198,0.793]
g4 = [0.286,0.736]
g5 = [0.327,0.664]
g6 = [0.445,0.596]
g7 = [0.141,0.564]
g8 = [0.25,0.586]
g9 = [0.254,0.827]
g10 = [0.366,0.699]
g11 = [0.331,0.652]
g12 = [0.439,0.604]

# %%
g1_neia = pd.read_csv('data_selten_games/game1_output_NEIA.csv')
g1_ibgamma = pd.read_csv('data_selten_games/game1_output_IBEGAMMA.csv')
g1_ibia = pd.read_csv('data_selten_games/game1_output_IBEIA.csv')
g1_ibia2 = pd.read_csv('data_selten_games/game1_output_IBE2IA.csv')

g2_neia = pd.read_csv('data_selten_games/game2_output_NEIA.csv')
g2_ibgamma = pd.read_csv('data_selten_games/game2_output_IBEGAMMA.csv')
g2_ibia = pd.read_csv('data_selten_games/game2_output_IBEIA.csv')
g2_ibia2 = pd.read_csv('data_selten_games/game2_output_IBE2IA.csv')

g3_neia = pd.read_csv('data_selten_games/game3_output_NEIA.csv')
g3_ibgamma = pd.read_csv('data_selten_games/game3_output_IBEGAMMA.csv')
g3_ibia = pd.read_csv('data_selten_games/game3_output_IBEIA.csv')
g3_ibia2 = pd.read_csv('data_selten_games/game3_output_IBE2IA.csv')

g4_neia = pd.read_csv('data_selten_games/game4_output_NEIA.csv')
g4_ibgamma = pd.read_csv('data_selten_games/game4_output_IBEGAMMA.csv')
g4_ibia = pd.read_csv('data_selten_games/game4_output_IBEIA.csv')
g4_ibia2 = pd.read_csv('data_selten_games/game4_output_IBE2IA.csv')

g5_neia = pd.read_csv('data_selten_games/game5_output_NEIA.csv')
g5_ibgamma = pd.read_csv('data_selten_games/game5_output_IBEGAMMA.csv')
g5_ibia = pd.read_csv('data_selten_games/game5_output_IBEIA.csv')
g5_ibia2 = pd.read_csv('data_selten_games/game5_output_IBE2IA.csv')

g6_neia = pd.read_csv('data_selten_games/game6_output_NEIA.csv')
g6_ibgamma = pd.read_csv('data_selten_games/game6_output_IBEGAMMA.csv')
g6_ibia = pd.read_csv('data_selten_games/game6_output_IBEIA.csv')
g6_ibia2 = pd.read_csv('data_selten_games/game6_output_IBE2IA.csv')

g7_neia = pd.read_csv('data_selten_games/game7_output_NEIA.csv')
g7_ibgamma = pd.read_csv('data_selten_games/game7_output_IBEGAMMA.csv')
g7_ibia = pd.read_csv('data_selten_games/game7_output_IBEIA.csv')
g7_ibia2 = pd.read_csv('data_selten_games/game7_output_IBE2IA.csv')

g8_neia = pd.read_csv('data_selten_games/game8_output_NEIA.csv')
g8_ibgamma = pd.read_csv('data_selten_games/game8_output_IBEGAMMA.csv')
g8_ibia = pd.read_csv('data_selten_games/game8_output_IBEIA.csv')
g8_ibia2 = pd.read_csv('data_selten_games/game8_output_IBE2IA.csv')

g9_neia = pd.read_csv('data_selten_games/game9_output_NEIA.csv')
g9_ibgamma = pd.read_csv('data_selten_games/game9_output_IBEGAMMA.csv')
g9_ibia = pd.read_csv('data_selten_games/game9_output_IBEIA.csv')
g9_ibia2 = pd.read_csv('data_selten_games/game9_output_IBE2IA.csv')

g10_neia = pd.read_csv('data_selten_games/game10_output_NEIA.csv')
g10_ibgamma = pd.read_csv('data_selten_games/game10_output_IBEGAMMA.csv')
g10_ibia = pd.read_csv('data_selten_games/game10_output_IBEIA.csv')
g10_ibia2 = pd.read_csv('data_selten_games/game10_output_IBE2IA.csv')

g11_neia = pd.read_csv('data_selten_games/game11_output_NEIA.csv')
g11_ibgamma = pd.read_csv('data_selten_games/game11_output_IBEGAMMA.csv')
g11_ibia = pd.read_csv('data_selten_games/game11_output_IBEIA.csv')
g11_ibia2 = pd.read_csv('data_selten_games/game11_output_IBE2IA.csv')

g12_neia = pd.read_csv('data_selten_games/game12_output_NEIA.csv')
g12_ibgamma = pd.read_csv('data_selten_games/game12_output_IBEGAMMA.csv')
g12_ibia = pd.read_csv('data_selten_games/game12_output_IBEIA.csv')
g12_ibia2 = pd.read_csv('data_selten_games/game12_output_IBE2IA.csv')

# %%
g1_ibegammaia = pd.read_csv('data_selten_games/game1_output_IBEGAMMAIA3.csv')
g2_ibegammaia = pd.read_csv('data_selten_games/game2_output_IBEGAMMAIA3.csv')
g3_ibegammaia = pd.read_csv('data_selten_games/game3_output_IBEGAMMAIA3.csv')
g4_ibegammaia = pd.read_csv('data_selten_games/game4_output_IBEGAMMAIA3.csv')
g5_ibegammaia = pd.read_csv('data_selten_games/game5_output_IBEGAMMAIA3.csv')
g6_ibegammaia = pd.read_csv('data_selten_games/game6_output_IBEGAMMAIA3.csv')
g7_ibegammaia = pd.read_csv('data_selten_games/game7_output_IBEGAMMAIA3.csv')
g8_ibegammaia = pd.read_csv('data_selten_games/game8_output_IBEGAMMAIA3.csv')
g9_ibegammaia = pd.read_csv('data_selten_games/game9_output_IBEGAMMAIA3.csv')
g10_ibegammaia = pd.read_csv('data_selten_games/game10_output_IBEGAMMAIA3.csv')
g11_ibegammaia = pd.read_csv('data_selten_games/game11_output_IBEGAMMAIA3.csv')
g12_ibegammaia = pd.read_csv('data_selten_games/game12_output_IBEGAMMAIA3.csv')

# %%
g1_ibegammaia = g1_ibegammaia.loc[g1_ibegammaia['q'] != 2]
g2_ibegammaia = g2_ibegammaia.loc[g2_ibegammaia['q'] != 2]
g3_ibegammaia = g3_ibegammaia.loc[g3_ibegammaia['q'] != 2]
g4_ibegammaia = g4_ibegammaia.loc[g4_ibegammaia['q'] != 2]
g5_ibegammaia = g5_ibegammaia.loc[g5_ibegammaia['q'] != 2]
g6_ibegammaia = g6_ibegammaia.loc[g6_ibegammaia['q'] != 2]
g7_ibegammaia = g7_ibegammaia.loc[g7_ibegammaia['q'] != 2]
g8_ibegammaia = g8_ibegammaia.loc[g8_ibegammaia['q'] != 2]
g9_ibegammaia = g9_ibegammaia.loc[g9_ibegammaia['q'] != 2]
g10_ibegammaia = g10_ibegammaia.loc[g10_ibegammaia['q'] != 2]
g11_ibegammaia = g11_ibegammaia.loc[g11_ibegammaia['q'] != 2]
g12_ibegammaia = g12_ibegammaia.loc[g12_ibegammaia['q'] != 2]

# %%
g1_neia = g1_neia.loc[g1_neia['q'] != 2]
g1_ibgamma = g1_ibgamma.loc[g1_ibgamma['q'] != 2]
g1_ibia = g1_ibia.loc[g1_ibia['q'] != 2]
g1_ibia2 = g1_ibia2.loc[g1_ibia2['q'] != 2]

g2_neia = g2_neia.loc[g2_neia['q'] != 2]
g2_ibgamma = g2_ibgamma.loc[g2_ibgamma['q'] != 2]
g2_ibia = g2_ibia.loc[g2_ibia['q'] != 2]
g2_ibia2 = g2_ibia2.loc[g2_ibia2['q'] != 2]

g3_neia = g3_neia.loc[g3_neia['q'] != 2]
g3_ibgamma = g3_ibgamma.loc[g3_ibgamma['q'] != 2]
g3_ibia = g3_ibia.loc[g3_ibia['q'] != 2]
g3_ibia2 = g3_ibia2.loc[g3_ibia2['q'] != 2]

g4_neia = g4_neia.loc[g4_neia['q'] != 2]
g4_ibgamma = g4_ibgamma.loc[g4_ibgamma['q'] != 2]
g4_ibia = g4_ibia.loc[g4_ibia['q'] != 2]
g4_ibia2 = g4_ibia2.loc[g4_ibia2['q'] != 2]

g5_neia = g5_neia.loc[g5_neia['q'] != 2]
g5_ibgamma = g5_ibgamma.loc[g5_ibgamma['q'] != 2]
g5_ibia = g5_ibia.loc[g5_ibia['q'] != 2]
g5_ibia2 = g5_ibia2.loc[g5_ibia2['q'] != 2]

g6_neia = g6_neia.loc[g6_neia['q'] != 2]
g6_ibgamma = g6_ibgamma.loc[g6_ibgamma['q'] != 2]
g6_ibia = g6_ibia.loc[g6_ibia['q'] != 2]
g6_ibia2 = g6_ibia2.loc[g6_ibia2['q'] != 2]

g7_neia = g7_neia.loc[g7_neia['q'] != 2]
g7_ibgamma = g7_ibgamma.loc[g7_ibgamma['q'] != 2]
g7_ibia = g7_ibia.loc[g7_ibia['q'] != 2]
g7_ibia2 = g7_ibia2.loc[g7_ibia2['q'] != 2]

g8_neia = g8_neia.loc[g8_neia['q'] != 2]
g8_ibgamma = g8_ibgamma.loc[g8_ibgamma['q'] != 2]
g8_ibia = g8_ibia.loc[g8_ibia['q'] != 2]
g8_ibia2 = g8_ibia2.loc[g8_ibia2['q'] != 2]

g9_neia = g9_neia.loc[g9_neia['q'] != 2]
g9_ibgamma = g9_ibgamma.loc[g9_ibgamma['q'] != 2]
g9_ibia = g9_ibia.loc[g9_ibia['q'] != 2]
g9_ibia2 = g9_ibia2.loc[g9_ibia2['q'] != 2]

g10_neia = g10_neia.loc[g10_neia['q'] != 2]
g10_ibgamma = g10_ibgamma.loc[g10_ibgamma['q'] != 2]
g10_ibia = g10_ibia.loc[g10_ibia['q'] != 2]
g10_ibia2 = g10_ibia2.loc[g10_ibia2['q'] != 2]

g11_neia = g11_neia.loc[g11_neia['q'] != 2]
g11_ibgamma = g11_ibgamma.loc[g11_ibgamma['q'] != 2]
g11_ibia = g11_ibia.loc[g11_ibia['q'] != 2]
g11_ibia2 = g11_ibia2.loc[g11_ibia2['q'] != 2]

g12_neia = g12_neia.loc[g12_neia['q'] != 2]
g12_ibgamma = g12_ibgamma.loc[g12_ibgamma['q'] != 2]
g12_ibia = g12_ibia.loc[g12_ibia['q'] != 2]
g12_ibia2 = g12_ibia2.loc[g12_ibia2['q'] != 2]

# %%
g11_neia = g11_neia.loc[g11_neia['q'] != 2]
g11_ibgamma = g11_ibgamma.loc[g11_ibgamma['q'] != 2]
g11_ibia = g11_ibia.loc[g11_ibia['q'] != 2]
g11_ibia2 = g11_ibia2.loc[g11_ibia2['q'] != 2]

g12_neia = g12_neia.loc[g12_neia['q'] != 2]
g12_ibgamma = g12_ibgamma.loc[g12_ibgamma['q'] != 2]
g12_ibia = g12_ibia.loc[g12_ibia['q'] != 2]
g12_ibia2 = g12_ibia2.loc[g12_ibia2['q'] != 2]

# %%
kwargs  =   {
             'linewidth':0.02, # line width of spot
             'alpha':0.3
            }
s=1
c_line='grey'
height_p = 2.75
color_s = 'darkcyan'

# %% [markdown]
# ### Game 1

# %%
g = sns.JointGrid(data=g1_neia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g1[0],g1[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color =color_s )

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 1 - NE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g1_ibgamma, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g1[0],g1[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 1 - IBEγ")

# %%
g = sns.JointGrid(data=g1_ibia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g1[0],g1[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 1 - IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g1_ibia2, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g1[0],g1[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 1 - IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=g1_ibegammaia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g1[0],g1[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 1 - IBEγ◦IA(α,β)")

# %% [markdown]
# ### Game 2

# %%
g = sns.JointGrid(data=g2_neia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g2[0],g2[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color =color_s )
        
g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 2 - NE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g2_ibgamma, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g2[0],g2[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)
        
g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 2 - IBEγ")

# %%
g = sns.JointGrid(data=g2_ibia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g2[0],g2[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)


g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 2 - IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g2_ibia2, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g2[0],g2[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 2 - IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=g2_ibegammaia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g2[0],g2[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 2 - IBEγ◦IA(α,β)")

# %% [markdown]
# ### Game 3

# %%
g = sns.JointGrid(data=g3_neia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g3[0],g3[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color =color_s )

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 3 - NE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g3_ibgamma, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g3[0],g3[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 3 - IBEγ")

# %%
g = sns.JointGrid(data=g3_ibia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g3[0],g3[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 3 - IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g3_ibia2, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g3[0],g3[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])        

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 3 - IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=g3_ibegammaia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g3[0],g3[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 3 - IBEγ◦IA(α,β)")

# %% [markdown]
# ### Game 4

# %%
g = sns.JointGrid(data=g4_neia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g4[0],g4[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color =color_s )
        
g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 4 - NE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g4_ibgamma, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g4[0],g4[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

        
g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 4 - IBEγ")

# %%
g = sns.JointGrid(data=g4_ibia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g4[0],g4[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)


g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 4 - IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g4_ibia2, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g4[0],g4[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 4 - IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=g4_ibegammaia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g4[0],g4[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 4 - IBEγ◦IA(α,β)")

# %% [markdown]
# ### Game 5

# %%
g = sns.JointGrid(data=g5_neia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g5[0],g5[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color =color_s )

        
g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 5 - NE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g5_ibgamma, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g5[0],g5[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 5 - IBEγ")

# %%
g = sns.JointGrid(data=g5_ibia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g5[0],g5[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 5 - IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g5_ibia2, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g5[0],g5[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 5 - IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=g5_ibegammaia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g5[0],g5[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 5 - IBEγ◦IA(α,β)")

# %% [markdown]
# ### Game 6

# %%
g = sns.JointGrid(data=g6_neia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g6[0],g6[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color =color_s )

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 6 - NE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g6_ibgamma, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g6[0],g6[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 6 - IBEγ")

# %%
g = sns.JointGrid(data=g6_ibia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g6[0],g6[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 6 - IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g6_ibia2, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g6[0],g6[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 6 - IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=g6_ibegammaia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g6[0],g6[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 6 - IBEγ◦IA(α,β)")

# %% [markdown]
# ### Game 7

# %%
g = sns.JointGrid(data=g7_neia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g7[0],g7[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color =color_s )
        
g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 7 - NE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g7_ibgamma, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g7[0],g7[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 7 - IBEγ")

# %%
g = sns.JointGrid(data=g7_ibia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g7[0],g7[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 7 - IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g7_ibia2, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g7[0],g7[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 7 - IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=g7_ibegammaia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g7[0],g7[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 7 - IBEγ◦IA(α,β)")

# %% [markdown]
# ### Game 8

# %%
g = sns.JointGrid(data=g8_neia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g8[0],g8[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color =color_s )
        
g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 8 - NE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g8_ibgamma, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g8[0],g8[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 8 - IBEγ")

# %%
g = sns.JointGrid(data=g8_ibia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g8[0],g8[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 8 - IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g8_ibia2, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g8[0],g8[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 8 - IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=g8_ibegammaia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g8[0],g8[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 8 - IBEγ◦IA(α,β)")

# %% [markdown]
# ### Game 9

# %%
g = sns.JointGrid(data=g9_neia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g9[0],g9[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color =color_s )
        
g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 9 - NE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g9_ibgamma, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g9[0],g9[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 9 - IBEγ")

# %%
g = sns.JointGrid(data=g9_ibia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g9[0],g9[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 9 - IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g9_ibia2, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g9[0],g9[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 9 - IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=g9_ibegammaia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g9[0],g9[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 9 - IBEγ◦IA(α,β)")

# %% [markdown]
# ### Game 10

# %%
g = sns.JointGrid(data=g10_neia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g10[0],g10[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color =color_s )

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 10 - NE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g10_ibgamma, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g10[0],g10[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 10 - IBEγ")

# %%
g = sns.JointGrid(data=g10_ibia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g10[0],g10[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 10 - IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g10_ibia2, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g10[0],g10[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 10 - IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=g10_ibegammaia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g10[0],g10[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 10 - IBEγ◦IA(α,β)")

# %% [markdown]
# ### Game 11

# %%
g = sns.JointGrid(data=g11_neia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g11[0],g11[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color =color_s )

        
g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 11 - NE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g11_ibgamma, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g11[0],g11[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 11 - IBEγ")

# %%
g = sns.JointGrid(data=g11_ibia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g11[0],g11[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)


g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 11 - IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g11_ibia2, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g11[0],g11[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 11 - IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=g11_ibegammaia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g11[0],g11[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 11 - IBEγ◦IA(α,β)")

# %% [markdown]
# ### Game 12

# %%
g = sns.JointGrid(data=g12_neia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g12[0],g12[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color =color_s )

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 12 - NE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g12_ibgamma, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g12[0],g12[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 12 - IBEγ")

# %%
g = sns.JointGrid(data=g12_ibia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g12[0],g12[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 12 - IBE◦IA(α,β)")

# %%
g = sns.JointGrid(data=g12_ibia2, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g12[0],g12[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 12 - IBE2◦IA(α,β)")

# %%
g = sns.JointGrid(data=g12_ibegammaia, x="PU", y="QL",height=height_p)
g.plot_joint(sns.scatterplot, s=s,**kwargs, color=color_s)
g.ax_joint.scatter(g12[0],g12[1], c='black', marker='x', s=75)
g.plot_marginals(sns.kdeplot, fill=True, color=color_s)

g.ax_joint.set_xticks([0, 0.5, 1])
g.ax_joint.set_yticks([0, 0.5, 1])

g.ax_marg_x.set_xlim(0, 1)
g.ax_marg_y.set_ylim(0, 1)
g.fig.suptitle("Game 12 - IBEγ◦IA(α,β)")
